# %%
from pi_down_load_models import download_model_to_local

MODEL_REPO = 2
MODEL_DIR = "/Users/carlos/Desktop/PileGo.Ai/ahum_llm/llms"
LLM_MODEL_TAG = "Qwen/Qwen3-0.6B"
    
download_model_to_local(LLM_MODEL_TAG, MODEL_DIR, MODEL_REPO)
# Out:
# 2026-02-09 13:45:07 - PI_LLM - INFO - 📥 开始下载模型: Qwen/Qwen3-0.6B 到 /Users/carlos/Desktop/PileGo.Ai/ahum_llm/llms
# 2026-02-09 13:45:07 - PI_LLM - INFO - 📁 模型文件已存在: /Users/carlos/Desktop/PileGo.Ai/ahum_llm/llms/Qwen/Qwen3-0.6B
# '/Users/carlos/Desktop/PileGo.Ai/ahum_llm/llms/Qwen/Qwen3-0.6B'
