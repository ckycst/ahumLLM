# %%
from pi_downloadModel import download_model_to_local

MODEL_REPO = 2
MODEL_DIR = "/Users/carlos/Desktop/PileGo.Ai/ahum_llm/llms"
LLM_MODEL_TAG = "Qwen/Qwen3-0.6B"
    
download_model_to_local(LLM_MODEL_TAG, MODEL_DIR, MODEL_REPO)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pi_downloadModel import download_model_to_local
#       3 MODEL_REPO = 2
#       4 MODEL_DIR = "/Users/carlos/Desktop/PileGo.Ai/ahum_llm/llms"
#
# ImportError: cannot import name 'download_model_to_local' from 'pi_downloadModel' (/Users/carlos/Desktop/PileGo.Ai/ahum_llm/PI_BASE/pi_downloadModel.py)
